# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 100)

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
features_df = pd.read_csv('data/training_set_features.csv', index_col='id')
labels_df = pd.read_csv('data/training_set_labels.csv', index_col='id')

# %%
np.testing.assert_array_equal(features_df.index.values, labels_df.index.values)

# %%
training_df = pd.concat([features_df, labels_df], axis=1, join='inner')
training_df
# Out:
#        amount_tsh date_recorded           funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14            Roman        1390         Roman
# 8776          0.0    2013-03-06          Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25     Lottery Club         686  World vision
# 67743         0.0    2013-01-28           Unicef         263        UNICEF
# 19728         0.0    2011-07-13      Action In A           0       Artisan
# ...           ...           ...              ...         ...           ...
# 60739        10.0    2013-05-03  Germany Republi        1210           CES
# 27263      4700.0    2011-05-07      Cefa-njombe        1212          Cefa
# 37057         0.0    2011-04-11              NaN           0           NaN
# 31282         0.0    2011-03-08            Malec           0          Musa
# 26348         0.0    2011-03-23       World Bank         191         World
#
# ...

# %%
# import pandas_profiling as pp
# profile = pp.ProfileReport(training_df, title = 'Report of Training Set', html = {'style':{'full_width': True}})
# profile

# %%
# profile.to_file(output_file="profile.html")

# %% [markdown]
# ## Missing Values

# %% [markdown]
# 1. funder - 6.1% - funder has the same entries missing as the installer - **missing category imputation** (since not missing at random)
# 2. installer - 6.2% - installer has the same entries missing as the funder - **missing category imputation** (since not missing at random)
# 3. public_meeting - 5.6% - missing at random - **random sample imputation** (not to distort the distribution)
# 4. scheme_management - 6.5% - **Company** (not to distort the distribution)
# 5. scheme_name - 47.4% - **missing category imputation** (since percentage of missing values too high)
# 6. permit - 5.1% - permit has somewhat similar entries missing as the funder and installer - **missing indicator** (since not missing at random)¶
# 7. subvillage - 0.6% - missing at random - **random sample imputation** (not to distort the distribution)
